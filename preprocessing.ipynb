# %%
import re
from pdfminer.high_level import extract_pages, extract_text

# %%
for page_layout in extract_pages("./data/Price-Monitoring-January-2-2024.pdf"):
    for element in page_layout:
        print(element)
# Out:
# <LTTextBoxHorizontal(0) 197.780,504.204,581.685,527.724 'Retail Price Range of Selected Agri-fishery Commodities at NCR Markets\nTuesday, January 2, 2024\n'>
# <LTTextBoxHorizontal(1) 113.810,464.728,145.105,486.794 'RICE\n(per kg)\n'>
# <LTTextBoxHorizontal(2) 185.180,491.612,275.646,498.572 ' LOCAL COMMERCIAL RICE\n'>
# <LTTextBoxHorizontal(3) 182.660,476.628,211.491,484.668 'Special\n'>
# <LTTextBoxHorizontal(4) 239.570,476.628,288.317,484.668 '52.00 - 65.00\n'>
# <LTTextBoxHorizontal(5) 180.020,457.068,214.286,465.108 'Premium\n'>
# <LTTextBoxHorizontal(6) 239.570,457.068,288.317,466.548 '-\n50.00 62.00\n'>
# <LTTextBoxHorizontal(7) 406.060,467.792,437.430,489.834 'FISH \n(per kg)\n'>
# <LTTextBoxHorizontal(8) 483.240,487.464,485.854,496.008 '-\n'>
# <LTTextBoxHorizontal(9) 491.590,487.464,721.897,496.008 '(02) 8920-2216 / (02) 8920-6434 / (02) 8926-8203 loc. 2180 / 2145\n'>
# ...

# %%
text = extract_text("./data/Price-Monitoring-January-2-2024.pdf")
print(text)
# Out:
# Retail Price Range of Selected Agri-fishery Commodities at NCR Markets
# Tuesday, January 2, 2024
#
# RICE
# (per kg)
#
#  LOCAL COMMERCIAL RICE
#
# Special
#
# 52.00 - 65.00
#
# Premium
#
# -
# 50.00 62.00
#
# FISH
# (per kg)
#
# -
#
# (02) 8920-2216 / (02) 8920-6434 / (02) 8926-8203 loc. 2180 / 2145
#
# - amas@da.gov.ph / aisd@da.gov.ph / cbpmt.amas2019@gmail.com
#
# IMPORTED C(cid:10)OMMERCIAL RICE
#
# Well-milled
#
# -
# 40.00 55.00
#
# Milkfish Bangus
#
# 140.00
#
# -
#
# 270.00
#
# Special
#
# 58.00 65.00
# -
#
# Regular Milled
#
# 50.00 - 53.00
#
# Tilapia
#
# 110.00
#
# -
#
# 160.00
#
# - 1st Floor, DA Building, DA Compound, Elliptical Road, DIliman Quezon City
#
# FRUITS
# (per kg)
#
# OTHER
# COMMODITIES
#
# Premium
#
# 52.00 - 60.00
#
# Well-milleda
#
# 51.00 - 51.00
#
# Regular Milled
#
# NOT AVAILABLE
#
# Corn (White)
# Glutinous
# Corn (Yellow)
# Japanese
#
# LIVESTOCK AND
# POULTRY
# PRODUCTS
#
# 380.00 - 480.00
#
# 305.00 440.00
# -
#
# 275.00 - 370.00
#
# ...

# %%
import tabula

tables = tabula.read_pdf("./data/Price-Monitoring-January-2-2024.pdf", pages="all")
print(tables)
# Out:
# Got stderr: Mar 09, 2025 5:48:45 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (10) in font ABCDEE+Century Gothic,Bold
# Mar 09, 2025 5:48:46 PM org.apache.pdfbox.rendering.TTFGlyph2D getPathForGID
# WARNING: No glyph for 10 in font ABCDEE+Century Gothic,Bold
# [                              Unnamed: 0  \
# 0                                   RICE
# 1                               (per kg)
# 2                                    NaN
# 3                                    NaN
# 4               IMPORTED COMMERCIAL RICE
# 5                                    NaN
# 6                  Special 58.00 - 65.00
# 7                                    NaN
# 8                  Premium 52.00 - 60.00
# 9                                    NaN
# 10                                     a
# 11             Well-milled 51.00 - 51.00
# 12                                   NaN
# 13                                   NaN
# ...
